# %%
# %matplotlib inline
from data_import_tools import import_arcadia_archived_data
from matplotlib import pyplot as plt

# %%
detector_dict, detector_list = import_arcadia_archived_data()

# %%
huntington_baldwin = detector_dict[3092] # video detector
# huntington_golden = detector_dict[3097] # loop detector
baldwin_elcaminoreal = detector_dict[3112] # loop detector
# huntington_lacadena = detector_dict[3094] # loop detector BROKEN
huntington_fairview = detector_dict[3101] # loop detector
# colorado_baldwin = detector_dict[3079] # loop detector

# %%
for det in huntington_baldwin:
    plt.figure()
    df = det.data
    # df.volume.plot()
    plt.plot(df.occupancy, df.volume, 'b.')
    plt.xlabel('occupancy')
    plt.ylabel('volume')
    plt.title(det.sensor_id)

# %%
for det in baldwin_elcaminoreal:
    plt.figure()
    df = det.data
    # df.volume.plot()
    plt.plot(df.occupancy, df.volume, 'b.')
    plt.xlabel('occupancy')
    plt.ylabel('volume')
    plt.title(det.sensor_id)

# %%
for det in huntington_fairview:
    plt.figure()
    df = det.data
    print det.sensor_type
    # df.volume.plot()
    plt.plot(df.occupancy, df.volume, 'b.')
    plt.xlabel('occupancy')
    plt.ylabel('volume')
    plt.title(det.sensor_id)
# Out:
# combined
# combined
# combined
# combined
